# %%
from pathlib import Path

from pprint import pprint

from clinicaio.dataset import BIDSDataset, Session
from clinicaio.types import DataType, SubjectId, Suffix
from clinicaio.image_query import ImageQuery

# IN _env.py:
#
# from pathlib import Path
# test_bids_read_path=Path("/path/to/BIDS_out")
from _env import test_bids_read_path

dataset = BIDSDataset.populate_from_dir(
    bids_dir=test_bids_read_path,
    subjects_info=False,
    sessions_info=False,
    # broken scans.tsv
    image_scans_info=False,
)

for image in dataset.all_images():
    print(image)

#dataset
# Out:
# UNHANDLED = ['.DS_Store', 'README', 'sub-ADNI041S1260/ses-M006/.DS_Store', 'sub-ADNI041S1260/.DS_Store']
# Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='magnitude1', scan_info=None)
# Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='phasediff', scan_info=None)
# Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='magnitude2', scan_info=None)
# Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='magnitude2', scan_info=None)
# Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='phasediff', scan_info=None)
# Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='magnitude1', scan_info=None)
# Image(data_type='dwi', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='dwi', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='T2starw', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='FLAIR', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='T1w', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='T1w', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='T1w', scan_info=None)
# Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FFDG", "rec": "coregavg"}), suffix='pet', scan_info=None)
# Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FFDG", "rec": "coregiso8"}), suffix='pet', scan_info=None)
# Image(data_type='dwi', nifti_extension='nii.gz', entities=Entities({}), suffix='dwi', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='FLAIR', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='T1w', scan_info=None)
# Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FAV45", "rec": "coregavg"}), suffix='pet', scan_info=None)
# Image(data_type='func', nifti_extension='nii.gz', entities=Entities({"task": "rest"}), suffix='bold', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='T1w', scan_info=None)
# Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FAV45", "run": "01"}), suffix='pet', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='T1w', scan_info=None)
# Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "11CPIB", "run": "01"}), suffix='pet', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='T1w', scan_info=None)
# Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FFDG", "rec": "coregavg"}), suffix='pet', scan_info=None)
# Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FFDG", "rec": "coregiso8"}), suffix='pet', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='T1w', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "02"}), suffix='T1w', scan_info=None)
# Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='magnitude1', scan_info=None)
# Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='phasediff', scan_info=None)
# Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='magnitude2', scan_info=None)
# Image(data_type='dwi', nifti_extension='nii.gz', entities=Entities({}), suffix='dwi', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='T1w', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='PDw', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='angio', scan_info=None)
# Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='T2w', scan_info=None)

# %%
image_query = ImageQuery(
	#subjects=["sub-ADNI027S0074"], 
	#sessions=["ses-M000"], 
	data_type=DataType.PET,
	#entities={"trc": "18FFDG", "rec": "coregiso8"},
	suffix="pet",
)
list(dataset.query_images_nifti_paths(image_query))
# Out:
# [PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-ADNI027S0074/ses-M000/pet/sub-ADNI027S0074_ses-M000_trc-18FFDG_rec-coregavg_pet.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-ADNI027S0074/ses-M000/pet/sub-ADNI027S0074_ses-M000_trc-18FFDG_rec-coregiso8_pet.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-ADNI027S0074/ses-M156/pet/sub-ADNI027S0074_ses-M156_trc-18FAV45_rec-coregavg_pet.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-OAS30011/ses-M054/pet/sub-OAS30011_ses-M054_trc-18FAV45_run-01_pet.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-OAS30011/ses-M000/pet/sub-OAS30011_ses-M000_trc-11CPIB_run-01_pet.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-ADNI041S1260/ses-M006/pet/sub-ADNI041S1260_ses-M006_trc-18FFDG_rec-coregavg_pet.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-ADNI041S1260/ses-M006/pet/sub-ADNI041S1260_ses-M006_trc-18FFDG_rec-coregiso8_pet.nii.gz')]

# %% [markdown]
# # QUERIES

# %% [markdown]
# ## Give me all tsv files

# %%
[subject.info for subject in dataset.all_subjects() if subject.info is not None]
# Out:
# []

# %%
[session.info for session in dataset.all_sessions() if session.info is not None]
# Out:
# []

# %%
[image.scan_info for image in dataset.all_images() if image.scan_info is not None]
# Out:
# []

# %% [markdown]
# ## Give me all images with this tracer (ex 18FFDG)

# %%
images = dataset.query_images(ImageQuery(entities={"trc": "18FFDG"}))
# p.ex
for image in images:
	print(image.get_nifti_image_path(), image)
# Out:
# /Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-ADNI027S0074/ses-M000/pet/sub-ADNI027S0074_ses-M000_trc-18FFDG_rec-coregavg_pet.nii.gz Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FFDG", "rec": "coregavg"}), suffix='pet', scan_info=None)
# /Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-ADNI027S0074/ses-M000/pet/sub-ADNI027S0074_ses-M000_trc-18FFDG_rec-coregiso8_pet.nii.gz Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FFDG", "rec": "coregiso8"}), suffix='pet', scan_info=None)
# /Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-ADNI041S1260/ses-M006/pet/sub-ADNI041S1260_ses-M006_trc-18FFDG_rec-coregavg_pet.nii.gz Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FFDG", "rec": "coregavg"}), suffix='pet', scan_info=None)
# /Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-ADNI041S1260/ses-M006/pet/sub-ADNI041S1260_ses-M006_trc-18FFDG_rec-coregiso8_pet.nii.gz Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FFDG", "rec": "coregiso8"}), suffix='pet', scan_info=None)

# %% [markdown]
# ## Give me all T1w images paths

# %%
list(dataset.query_images_nifti_paths(ImageQuery(suffix="T1w")))
# Out:
# [PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-OAS30542/ses-M126/anat/sub-OAS30542_ses-M126_run-01_T1w.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-ADNI027S0074/ses-M096/anat/sub-ADNI027S0074_ses-M096_T1w.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-ADNI027S0074/ses-M000/anat/sub-ADNI027S0074_ses-M000_T1w.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-ADNI027S0074/ses-M156/anat/sub-ADNI027S0074_ses-M156_T1w.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-OAS30011/ses-M054/anat/sub-OAS30011_ses-M054_run-01_T1w.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-OAS30011/ses-M000/anat/sub-OAS30011_ses-M000_run-01_T1w.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-ADNI041S1260/ses-M006/anat/sub-ADNI041S1260_ses-M006_T1w.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-OAS30003/ses-M018/anat/sub-OAS30003_ses-M018_run-01_T1w.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-OAS30003/ses-M018/anat/sub-OAS30003_ses-M018_run-02_T1w.nii.gz'),
#  PosixPath('/Users/emilie.heffernan/Downloads/BIDS_clinicaio/sub-IXI661/ses-M000/anat/sub-IXI661_ses-M000_T1w.nii.gz')]

# %% [markdown]
# ## Give me all modalities for this one subject

# %%
subject_id = SubjectId("sub-ADNI027S0074")
#subject_id = SubjectId("sub-AIBL1455")
print(subject_id)
subject = dataset.subject_by_id(subject_id)
assert subject is not None
set(image.suffix for image in subject.all_images())
# Out:
# sub-ADNI027S0074
# {'FLAIR', 'T1w', 'bold', 'dwi', 'pet'}

# %% [markdown]
# ## Give me all sessions for this one subject

# %%
print(subject_id)
pprint(list(subject.all_sessions()))
# Out:
# sub-ADNI027S0074
# [Session(id='ses-M096',
#          _images={'anat': [Image(data_type='anat',
#                                  nifti_extension='nii.gz',
#                                  entities=Entities({}),
#                                  suffix='T1w',
#                                  scan_info=None)]},
#          info=None),
#  Session(id='ses-M000',
#          _images={'anat': [Image(data_type='anat',
#                                  nifti_extension='nii.gz',
#                                  entities=Entities({}),
#                                  suffix='T1w',
#                                  scan_info=None)],
#                   'pet': [Image(data_type='pet',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({"trc": "18FFDG", "rec": "coregavg"}),
#                                 suffix='pet',
#                                 scan_info=None),
#                           Image(data_type='pet',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({"trc": "18FFDG", "rec": "coregiso8"}),
#                                 suffix='pet',
#                                 scan_info=None)]},
#          info=None),
#  Session(id='ses-M156',
#          _images={'anat': [Image(data_type='anat',
#                                  nifti_extension='nii.gz',
#                                  entities=Entities({}),
#                                  suffix='FLAIR',
#                                  scan_info=None),
#                            Image(data_type='anat',
#                                  nifti_extension='nii.gz',
#                                  entities=Entities({}),
#                                  suffix='T1w',
#                                  scan_info=None)],
#                   'dwi': [Image(data_type='dwi',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({}),
#                                 suffix='dwi',
#                                 scan_info=None)],
#                   'func': [Image(data_type='func',
#                                  nifti_extension='nii.gz',
#                                  entities=Entities({"task": "rest"}),
#                                  suffix='bold',
#                                  scan_info=None)],
#                   'pet': [Image(data_type='pet',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({"trc": "18FAV45", "rec": "coregavg"}),
#                                 suffix='pet',
#                                 scan_info=None)]},
#          info=None)]

# %% [markdown]
# ## Give me all subjects/sessions that have both a T1 and a PET image for the same session

# %%
def has_t1_and_pet(session: Session):
	has_t1 = any(image.suffix == Suffix("T1w") for image in session.all_images())
	
	return has_t1 and next(iter(session.images_by_data_type(DataType.PET)), None) is None

subjects_and_sessions_with_t1_and_pet = filter(
	has_t1_and_pet,
	dataset.all_sessions(),
)
for session in subjects_and_sessions_with_t1_and_pet:
    subject = session.parent_subject
    print(subject.id)
    pprint(session)
    print("========================")
# Out:
# sub-OAS30542
# Session(id='ses-M126',
#         _images={'anat': [Image(data_type='anat',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({"run": "01"}),
#                                 suffix='T2starw',
#                                 scan_info=None),
#                           Image(data_type='anat',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({"run": "01"}),
#                                 suffix='FLAIR',
#                                 scan_info=None),
#                           Image(data_type='anat',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({"run": "01"}),
#                                 suffix='T1w',
#                                 scan_info=None)],
#                  'dwi': [Image(data_type='dwi',
#                                nifti_extension='nii.gz',
#                                entities=Entities({"run": "01"}),
#                                suffix='dwi',
#                                scan_info=None)]},
#         info=None)
# ========================
# sub-ADNI027S0074
# Session(id='ses-M096',
#         _images={'anat': [Image(data_type='anat',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({}),
#                                 suffix='T1w',
#                                 scan_info=None)]},
#         info=None)
# ========================
# sub-OAS30003
# Session(id='ses-M018',
#         _images={'anat': [Image(data_type='anat',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({"run": "01"}),
#                                 suffix='T1w',
#                                 scan_info=None),
#                           Image(data_type='anat',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({"run": "02"}),
#                                 suffix='T1w',
#                                 scan_info=None)]},
#         info=None)
# ========================
# sub-IXI661
# Session(id='ses-M000',
#         _images={'anat': [Image(data_type='anat',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({}),
#                                 suffix='T1w',
#                                 scan_info=None),
#                           Image(data_type='anat',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({}),
#                                 suffix='PDw',
#                                 scan_info=None),
#                           Image(data_type='anat',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({}),
#                                 suffix='angio',
#                                 scan_info=None),
#                           Image(data_type='anat',
#                                 nifti_extension='nii.gz',
#                                 entities=Entities({}),
#                                 suffix='T2w',
#                                 scan_info=None)],
#                  'dwi': [Image(data_type='dwi',
#                                nifti_extension='nii.gz',
#                                entities=Entities({}),
#                                suffix='dwi',
#                                scan_info=None)]},
#         info=None)
# ========================

# %% [markdown]
# ## Give me the subjects that have more than one session

# %%
pprint(list(filter(lambda subject: subject.sessions_count() > 1, dataset.all_subjects())))
# Out:
# [Subject(id='sub-ADNI003S6432',
#          info=None,
#          _sessions={'ses-M012': Session(id='ses-M012',
#                                         _images={'fmap': [Image(data_type='fmap',
#                                                                 nifti_extension='nii.gz',
#                                                                 entities=Entities({}),
#                                                                 suffix='magnitude2',
#                                                                 scan_info=None),
#                                                           Image(data_type='fmap',
#                                                                 nifti_extension='nii.gz',
#                                                                 entities=Entities({}),
#                                                                 suffix='phasediff',
#                                                                 scan_info=None),
#                                                           Image(data_type='fmap',
#                                                                 nifti_extension='nii.gz',
#                                                                 entities=Entities({}),
#                                                                 suffix='magnitude1',
#                                                                 scan_info=None)]},
#                                         info=None),
#                     'ses-M000': Session(id='ses-M000',
#                                         _images={'fmap': [Image(data_type='fmap',
#                                                                 nifti_extension='nii.gz',
#                                                                 entities=Entities({}),
#                                                                 suffix='magnitude1',
#                                                                 scan_info=None),
#                                                           Image(data_type='fmap',
#                                                                 nifti_extension='nii.gz',
#                                                                 entities=Entities({}),
#                                                                 suffix='phasediff',
#                                                                 scan_info=None),
#                                                           Image(data_type='fmap',
#                                                                 nifti_extension='nii.gz',
#                                                                 entities=Entities({}),
#                                                                 suffix='magnitude2',
#                                                                 scan_info=None)]},
#                                         info=None)}),
#  Subject(id='sub-ADNI027S0074',
#          info=None,
#          _sessions={'ses-M156': Session(id='ses-M156',
#                                         _images={'anat': [Image(data_type='anat',
#                                                                 nifti_extension='nii.gz',
#                                                                 entities=Entities({}),
#                                                                 suffix='FLAIR',
#                                                                 scan_info=None),
#                                                           Image(data_type='anat',
#                                                                 nifti_extension='nii.gz',
#                                                                 entities=Entities({}),
#                                                                 suffix='T1w',
#                                                                 scan_info=None)],
#                                                  'dwi': [Image(data_type='dwi',
#                                                                nifti_extension='nii.gz',
#                                                                entities=Entities({}),
#                                                                suffix='dwi',
#                                                                scan_info=None)],
#                                                  'func': [Image(data_type='func',
#                                                                 nifti_extension='nii.gz',
#                                                                 entities=Entities({"task": "rest"}),
#                                                                 suffix='bold',
#                                                                 scan_info=None)],
#                                                  'pet': [Image(data_type='pet',
#                                                                nifti_extension='nii.gz',
#                                                                entities=Entities({"trc": "18FAV45", "rec": "coregavg"}),
#                                                                suffix='pet',
#                                                                scan_info=None)]},
#                                         info=None),
#                     'ses-M000': Session(id='ses-M000',
#                                         _images={'anat': [Image(data_type='anat',
#                                                                 nifti_extension='nii.gz',
#                                                                 entities=Entities({}),
#                                                                 suffix='T1w',
#                                                                 scan_info=None)],
#                                                  'pet': [Image(data_type='pet',
#                                                                nifti_extension='nii.gz',
#                                                                entities=Entities({"trc": "18FFDG", "rec": "coregavg"}),
#                                                                suffix='pet',
#                                                                scan_info=None),
#                                                          Image(data_type='pet',
#                                                                nifti_extension='nii.gz',
#                                                                entities=Entities({"trc": "18FFDG", "rec": "coregiso8"}),
#                                                                suffix='pet',
#                                                                scan_info=None)]},
#                                         info=None),
#                     'ses-M096': Session(id='ses-M096',
#                                         _images={'anat': [Image(data_type='anat',
#                                                                 nifti_extension='nii.gz',
#                                                                 entities=Entities({}),
#                                                                 suffix='T1w',
#                                                                 scan_info=None)]},
#                                         info=None)}),
#  Subject(id='sub-OAS30011',
#          info=None,
#          _sessions={'ses-M054': Session(id='ses-M054',
#                                         _images={'anat': [Image(data_type='anat',
#                                                                 nifti_extension='nii.gz',
#                                                                 entities=Entities({"run": "01"}),
#                                                                 suffix='T1w',
#                                                                 scan_info=None)],
#                                                  'pet': [Image(data_type='pet',
#                                                                nifti_extension='nii.gz',
#                                                                entities=Entities({"trc": "18FAV45", "run": "01"}),
#                                                                suffix='pet',
#                                                                scan_info=None)]},
#                                         info=None),
#                     'ses-M000': Session(id='ses-M000',
#                                         _images={'anat': [Image(data_type='anat',
#                                                                 nifti_extension='nii.gz',
#                                                                 entities=Entities({"run": "01"}),
#                                                                 suffix='T1w',
#                                                                 scan_info=None)],
#                                                  'pet': [Image(data_type='pet',
#                                                                nifti_extension='nii.gz',
#                                                                entities=Entities({"trc": "11CPIB", "run": "01"}),
#                                                                suffix='pet',
#                                                                scan_info=None)]},
#                                         info=None)})]

# %% [markdown]
# ## Check that all subjects/sessions have FLAIR images

# %%
def session_has_flair_image(session: Session):
	any(image.suffix == Suffix("FLAIR") for image in session.all_images())

all(session_has_flair_image(session) for session in dataset.all_sessions())
# Out:
# False

# %% [markdown]
# ## Give me all the modalities available for each subject for this list of subjects

# %%
subjects = dataset.all_subjects()
[(
    subject,
	set(
		image.suffix
		for image in subject.all_images()
	),
) for subject in subjects]
# Out:
# [(Subject(id='sub-ADNI003S6432', info=None, _sessions={'ses-M000': Session(id='ses-M000', _images={'fmap': [Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='magnitude1', scan_info=None), Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='phasediff', scan_info=None), Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='magnitude2', scan_info=None)]}, info=None), 'ses-M012': Session(id='ses-M012', _images={'fmap': [Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='magnitude2', scan_info=None), Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='phasediff', scan_info=None), Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='magnitude1', scan_info=None)]}, info=None)}),
#   {'magnitude1', 'magnitude2', 'phasediff'}),
#  (Subject(id='sub-OAS30542', info=None, _sessions={'ses-M126': Session(id='ses-M126', _images={'dwi': [Image(data_type='dwi', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='dwi', scan_info=None)], 'anat': [Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='T2starw', scan_info=None), Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='FLAIR', scan_info=None), Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='T1w', scan_info=None)]}, info=None)}),
#   {'FLAIR', 'T1w', 'T2starw', 'dwi'}),
#  (Subject(id='sub-ADNI027S0074', info=None, _sessions={'ses-M096': Session(id='ses-M096', _images={'anat': [Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='T1w', scan_info=None)]}, info=None), 'ses-M000': Session(id='ses-M000', _images={'anat': [Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='T1w', scan_info=None)], 'pet': [Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FFDG", "rec": "coregavg"}), suffix='pet', scan_info=None), Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FFDG", "rec": "coregiso8"}), suffix='pet', scan_info=None)]}, info=None), 'ses-M156': Session(id='ses-M156', _images={'dwi': [Image(data_type='dwi', nifti_extension='nii.gz', entities=Entities({}), suffix='dwi', scan_info=None)], 'anat': [Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='FLAIR', scan_info=None), Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='T1w', scan_info=None)], 'pet': [Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FAV45", "rec": "coregavg"}), suffix='pet', scan_info=None)], 'func': [Image(data_type='func', nifti_extension='nii.gz', entities=Entities({"task": "rest"}), suffix='bold', scan_info=None)]}, info=None)}),
#   {'FLAIR', 'T1w', 'bold', 'dwi', 'pet'}),
#  (Subject(id='sub-OAS30011', info=None, _sessions={'ses-M054': Session(id='ses-M054', _images={'anat': [Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='T1w', scan_info=None)], 'pet': [Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FAV45", "run": "01"}), suffix='pet', scan_info=None)]}, info=None), 'ses-M000': Session(id='ses-M000', _images={'anat': [Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='T1w', scan_info=None)], 'pet': [Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "11CPIB", "run": "01"}), suffix='pet', scan_info=None)]}, info=None)}),
#   {'T1w', 'pet'}),
#  (Subject(id='sub-ADNI041S1260', info=None, _sessions={'ses-M006': Session(id='ses-M006', _images={'anat': [Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='T1w', scan_info=None)], 'pet': [Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FFDG", "rec": "coregavg"}), suffix='pet', scan_info=None), Image(data_type='pet', nifti_extension='nii.gz', entities=Entities({"trc": "18FFDG", "rec": "coregiso8"}), suffix='pet', scan_info=None)]}, info=None)}),
#   {'T1w', 'pet'}),
#  (Subject(id='sub-OAS30003', info=None, _sessions={'ses-M018': Session(id='ses-M018', _images={'anat': [Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "01"}), suffix='T1w', scan_info=None), Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({"run": "02"}), suffix='T1w', scan_info=None)]}, info=None)}),
#   {'T1w'}),
#  (Subject(id='sub-ADNI116S4855', info=None, _sessions={'ses-M060': Session(id='ses-M060', _images={'fmap': [Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='magnitude1', scan_info=None), Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='phasediff', scan_info=None), Image(data_type='fmap', nifti_extension='nii.gz', entities=Entities({}), suffix='magnitude2', scan_info=None)]}, info=None)}),
#   {'magnitude1', 'magnitude2', 'phasediff'}),
#  (Subject(id='sub-IXI661', info=None, _sessions={'ses-M000': Session(id='ses-M000', _images={'dwi': [Image(data_type='dwi', nifti_extension='nii.gz', entities=Entities({}), suffix='dwi', scan_info=None)], 'anat': [Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='T1w', scan_info=None), Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='PDw', scan_info=None), Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='angio', scan_info=None), Image(data_type='anat', nifti_extension='nii.gz', entities=Entities({}), suffix='T2w', scan_info=None)]}, info=None)}),
#   {'PDw', 'T1w', 'T2w', 'angio', 'dwi'})]

# %% [markdown]
# ## Give me all the modalities available for all subjects for this list of subjects

# %%
print({ f"{image.suffix}" for subject in dataset.all_subjects() for image in subject.all_images() })
# Out:
# {'pet', 'angio', 'FLAIR', 'T2starw', 'bold', 'PDw', 'magnitude1', 'T1w', 'phasediff', 'T2w', 'dwi', 'magnitude2'}

# %% [markdown]
# ## Can you tell me if all subjects have only one session

# %%
all(subject.sessions_count() == 1 for subject in dataset.all_subjects())
# Out:
# False

# %%
# Roundtrip testing

import shutil
import os
print("WRITING COPY OF DATASET")
dataset._bids_path = Path("/tmp/bids_foobar_write")
shutil.rmtree(dataset._bids_path, ignore_errors=True)
dataset.write_to_folder()
for session in dataset.all_sessions():
	images = list(session.all_images())

	session._images = {}
	with session.write_images() as images_writer:
		for image in images:
			added_image = images_writer.write_image(
				data_type=image.data_type,
				nifti_extension=image.nifti_extension,
				entities=image.entities,
				suffix=image.suffix,
				scan_info=image.scan_info
			)
			nifti_path = added_image.get_nifti_image_path()
			with open(nifti_path, mode="x") as f:
				print("NIFTI IMAGE", file=f)


dataset2 = BIDSDataset.populate_from_dir(dataset._bids_path, sessions_info=True, subjects_info=True, image_scans_info=True)
#print(dataset2.__repr__(), file=open("aaaa", mode="w"))
#print(dataset.__repr__(), file=open("bbbb", mode="w"))
assert dataset2 == dataset
# Out:
# WRITING COPY OF DATASET
# UNHANDLED = []
